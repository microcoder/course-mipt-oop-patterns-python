# %% [markdown]
# ## Тестирование и отладка программ
#
# [Конспект по первой неделе в формате PDF от Mail.ru Group](1/Python2_Coursera_Week1.pdf)
#
# ### Структурное программирование
#
# #### [Профессионализм в программировании](1/1.2.1_profi.ipynb)
#
# #### [Культура программирования](1/1.2.2_culture_of_programming.ipynb)
#
# #### [Выбор идентификаторов](1/1.2.3_select_id.ipynb)
#
# #### [Структурное программирование](1/1.2.4_struct_programming.ipynb)
#
# #### [Проектирование приложения «сверху-вниз»](1/1.2.5_projecting_from_above_to_below.ipynb)
#
# ### Тестирование
#
# #### [Зачем нужно тестировать программы](1/1.3.1_why_you_need_to_test_programs.ipynb)
#
# #### [Контрактное программирование](1/1.3.2_contract_programming.ipynb)
#
# #### [Утверждения assert](1/1.3.3_assert.ipynb)
#
# #### [Модульное тестирование и Test-Driven Development](1/1.3.4_tdd.ipynb)
#
# #### [Пример разработки через тестирование](1/1.3.5_example_tdd.ipynb)
#
# #### [Библиотека doctest](1/1.3.6_doctest.ipynb)
#
# #### [Библиотека unittest](1/1.3.7_unittest.ipynb)
#
# #### [Использование unittest](1/1.3.8_using_unittest.ipynb)
#
# ## Объектно-ориентированное проектирование
#
# ### Введение в ООП
#
# #### [Чем хорошо объектно-ориентированное программирование?](2/2.1.1_oop.ipynb)
#
# #### [Отличие класса от объекта]()
#
# #### [Отличие интерфейса класса от реализации]()
#
# ### Парадигмы ООП
#
# #### [Инкапсуляция и полиморфизм в Python]()
#
# #### [SOLID принципы ООП]()
#
# ### Разработка системы классов
#
# #### [Парадигма наследования в Python]()
#
# #### [Абстрактные классы и библиотека abc]()
#
# #### [UML-нотация и диаграммы классов]()
#
# ### Рефакторинг кода
#
# #### [Объектно-ориентированный рефакторинг программ]()
